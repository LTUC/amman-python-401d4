# %% [markdown]
# # Images are just Arrays!

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from random import random

# %%
img = mpimg.imread('./onion.png')

# %%
print('length, aka number of rows:', len(img))
print('height, aka number of columns in each row:', len(img[0]))
print('depth, in this case the color channels', len(img[0][0]))
print('Easier just to ask for the shape', img.shape)
# Out:
# length, aka number of rows: 800
# height, aka number of columns in each row: 787
# depth, in this case the color channels 4
# Easier just to ask for the shape (800, 787, 4)

# %% [markdown]
# ## Render image
# We'll learn more about Matplotlib later, for now just feed it the array/image and behold

# %%
imgplot = plt.imshow(img)

# %%
plt.imshow(img[0:250,0:350,:])

# %%
dom_v = np.vectorize(lambda val : round(val))
extreme_img = dom_v(img)
plt.imshow(extreme_img)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

img = mpimg.imread('onion.png')     
gray = rgb2gray(img)    
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()

# %%
img = mpimg.imread('./onion.png')
img = img * [0,1,0,1]
plt.imshow(img)

# %%
cube = np.random.uniform(size=(3,3,4))
cube
# Out:
# array([[[0.28726081, 0.69711798, 0.7754938 , 0.46507524],
#         [0.73923499, 0.58581709, 0.74188463, 0.78783044],
#         [0.11132824, 0.07888863, 0.13263533, 0.72198463]],
#
#        [[0.2427495 , 0.98811363, 0.66732526, 0.35820473],
#         [0.39493121, 0.87836751, 0.74310755, 0.74479907],
#         [0.3275368 , 0.34728716, 0.32527659, 0.93768844]],
#
#        [[0.78752149, 0.44522815, 0.88912287, 0.5843221 ],
#         [0.69186764, 0.27259941, 0.60635861, 0.82239815],
#         [0.71136531, 0.68179357, 0.08165258, 0.98521973]]])

# %%
plt.imshow(cube)

# %%
board = np.random.rand(3,3,4)

print(type(board[0,0]))

def show_board(board):
    board[0,0] = [0,0,0,0] # White cell
    board[1,1] = [0,0,0,0] # White cell
    plt.imshow(board)
    assert board[0,0,0]==0
    print("All went fine!!!")
show_board(board)
# Out:
# <class 'numpy.ndarray'>
# All went fine!!!
